# %%
import os
import glob
import pandas as pd
from sklearn.model_selection import train_test_split
carpeta = "CSV"
archivos_csv = glob.glob(os.path.join(carpeta, "*.csv"))

# Leer y combinar todos los archivos CSV en un solo DataFrame
dataframes = [pd.read_csv(archivo) for archivo in archivos_csv]

# Combinar todos los DataFrames en uno solo (opcional, depende de lo que quieras hacer)
df_combined = pd.concat(dataframes, ignore_index=True)
# Quitar la primera columna (Unnamed: 0) si es innecesaria
df_combined = df_combined.drop(columns=['Unnamed: 0'])


data = df_combined.loc[df_combined['corrected1'].notna() | df_combined['corrected2'].notna()]

# %%
import pandas as pd
import json

# Carga el archivo JSON
with open('llama-tuned.json', 'r', encoding='utf-8') as file:
    json_data = json.load(file)

# Crea un DataFrame desde el JSON
json_df = pd.DataFrame(json_data)

# Esto creará una nueva columna 'texto_model' que contiene solo el texto entre <start_of_turn>model y <end_of_turn>
# Realizar el merge basándose en 'input' del JSON y 'essay' del DataFrame
combined_df = pd.merge(json_df, data, left_on='input', right_on='essay')

# Eliminar la columna 'essay' si ya no es necesaria
combined_df = combined_df.drop(columns=['essay'])

combined_df
# Out:
#                                                  input  \
# 0    Un evento terrible que ocurre en mi vida hace ...
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3    En mi vida, yo tengo un persona especial. Mi p...
# 4    Mi vacaciones perfecto would be ir a la playa ...
# ..                                                 ...
# 257  Yo tengo mucha gente en mi vida. Tengo mi fami...
# 258  Una historia hermosa puede ser describida muy ...
# 259  Una persona famosa es Michael Jordan. Yo pense...
# 260  Tengo un cuento terrible durante la vacación d...
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                             correction  \
# 0    Un evento terrible que ocurre en mi vida hace ...
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3    En mi vida, yo tengo una persona especial. Mi ...
# 4    Mi vacación perfecto sería ir a la playa con m...
# ..                                                 ...
# 257  Tengo mucha gente en mi vida. Tengo mi familia...
# 258  Una historia hermosa puede ser descrita muy di...
# 259  Una persona famosa es Michael Jordan. Yo piens...
# 260  Tengo una historia horrible durante la vacació...
# 261  Chris Martin es un cantante, pianista y guitar...
#
#                                                 target      id     prompt  \
# 0    Un evento terrible que ocurrió en mi vida hace...  169632   terrible
# 1    Una persona famosa que me inspira es Selena Qu...  159244     famous
# 2    El presidente Trump es muy buen presidente. No...  190771     famous
# 3    En mi vida, yo tengo un persona especial. Mi p...  171906    special
# 4    ﻿  Mis vacaciones perfectas serían ir a la pla...  146799   vacation
# ..                                                 ...     ...        ...
# 257  Tengo mucha gente en mi vida. Tengo a mi famil...  134174    special
# 258  Una historia hermosa puede ser descrita de man...  231920  beautiful
# 259  ﻿Una persona famosa es Michael Jordan. Yo pien...  176089     famous
# 260  Tengo un cuento terrible durante las vacacione...  172548   terrible
# 261  Chris Martin es un cantante, pianista, y guita...  128671     famous
#
#     quarter  course   age  gender l1 language  ...  \
# 0       F18  SPA 24    19  Female     English  ...
# 1       S17   SPA 3    19  Female     English  ...
# 2       S18   SPA 1  Male      31     English  ...
# 3       S19   SPA 3    18  Female     English  ...
# 4       S17   SPA 2    19  Female     English  ...
# ..      ...     ...   ...     ...         ...  ...
# 257     W19  SPA 21    22  Female     English  ...
# 258     S20  SPA 33    21     NaN         NaN  ...
# 259     F17   SPA 1    18    Male     English  ...
# 260     F18   SPA 1    19  Female    Mandarin  ...
# 261     F17  SPA 21   21   Female     English  ...
#
#                                  a personal annotator1  \
# 0                                                  NaN
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3                                                  NaN
# 4    Mi vacaciones perfecto would be ir a la playa ...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259  Una persona famosa es Michael Jordan. Yo pense...
# 260                                                NaN
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                  a personal annotator2  \
# 0                                                  NaN
# 1    Una persona famosa que me inspira es Selena Qu...
# 2                                                  NaN
# 3                                                  NaN
# 4    Mi vacaciones perfecto would be ir a la playa ...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259  Una persona famosa es Michael Jordan. Yo pense...
# 260                                                NaN
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                               gender-number annotator1  \
# 0                                                  NaN
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3                                                  NaN
# 4    [Mi]{mis}<na:ps:det:inan> vacaciones [perfecto...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259  Una persona famosa es Michael Jordan. Yo pense...
# 260                                                NaN
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                               gender-number annotator2  \
# 0                                                  NaN
# 1    Una persona famosa que me inspira es Selena Qu...
# 2                                                  NaN
# 3                                                  NaN
# 4    [Mi]{mis}<na:ps:det:inan> vacaciones [perfecto...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
#
#                                updated anntoation ann1  \
# 0    ﻿Un evento terrible que ocurre en mi vida hace...
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3    En mi vida, yo tengo un persona especial. Mi p...
# 4    ﻿  [Mi]{Mis}<na:adj> vacaciones perfecto would...
# ..                                                 ...
# 257  [Yo]{}<pr:su:pron> tengo mucha gente en mi vid...
# 258  Una historia hermosa puede ser describida muy ...
# 259  Una persona famosa es Michael Jordan. [Yo]{}<p...
# 260  Tengo un cuento terrible durante [la]{las}<in:...
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                updated annotation ann2  \
# 0    Un evento terrible que [ocurre]{ocurrió}<fs:st...
# 1    ﻿Una persona famosa que me inspira es Selena Q...
# 2    El Presidente Trump es muy buen Presidente, [é...
# 3    En mi vida, [yo]{}<pr:su:pron> tengo [un]{una}...
# 4    [Mi]{Mis}<na:det> vacaciones [perfecto]{perfec...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260  Tengo un cuento terrible durante [la]{las}<in:...
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                  verbs annotation ann1 verbs annotation ann2  \
# 0                                                  NaN                   NaN
# 1                                                  NaN                   NaN
# 2                                                  NaN                   NaN
# 3                                                  NaN                   NaN
# 4                                                  NaN                   NaN
# ..                                                 ...                   ...
# 257                                                NaN                   NaN
# 258  Una historia hermosa puede ser describida muy ...                   NaN
# 259                                                NaN                   NaN
# 260                                                NaN                   NaN
# 261                                                NaN                   NaN
#
#                                             corrected1  \
# 0    Un evento terrible que ocurrió en mi vida hace...
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El presidente Trump es muy buen presidente. No...
# 3    En mi vida, yo tengo un persona especial. Mi p...
# 4    ﻿  Mis vacaciones perfectas serían ir a la pla...
# ..                                                 ...
# 257  Tengo mucha gente en mi vida. Tengo a mi famil...
# 258  Una historia hermosa puede ser descrita de man...
# 259  Una persona famosa es Michael Jordan. Creo que...
# 260  Tengo un cuento terrible durante las vacacione...
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                             corrected2
# 0                                                  NaN
# 1    ﻿Una persona famosa que me inspira es Selena Q...
# 2                                                  NaN
# 3                                                  NaN
# 4    Mis vacaciones perfectas serían ir a la playa ...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259  ﻿Una persona famosa es Michael Jordan. Yo pien...
# 260                                                NaN
# 261  Chris Martin es un cantante, pianista y guitar...
#
# [262 rows x 28 columns]

# %%
import pandas as pd

# Supongamos que combined_df ya está definido

# Función para comprobar si un valor es un número
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# Corregir valores intercambiados entre 'gender' y 'age'
for index, row in combined_df.iterrows():
    if isinstance(row['gender'], int) or is_number(row['gender']):
        # Si 'gender' contiene un número, probablemente estén intercambiados
        combined_df.at[index, 'gender'], combined_df.at[index, 'age'] = row['age'], row['gender']

# Opcional: convertir la columna 'age' a numérica para asegurarse de que todos son números
combined_df['age'] = pd.to_numeric(combined_df['age'], errors='coerce')

combined_df
# Out:
#                                                  input  \
# 0    Un evento terrible que ocurre en mi vida hace ...
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3    En mi vida, yo tengo un persona especial. Mi p...
# 4    Mi vacaciones perfecto would be ir a la playa ...
# ..                                                 ...
# 257  Yo tengo mucha gente en mi vida. Tengo mi fami...
# 258  Una historia hermosa puede ser describida muy ...
# 259  Una persona famosa es Michael Jordan. Yo pense...
# 260  Tengo un cuento terrible durante la vacación d...
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                             correction  \
# 0    Un evento terrible que ocurre en mi vida hace ...
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3    En mi vida, yo tengo una persona especial. Mi ...
# 4    Mi vacación perfecto sería ir a la playa con m...
# ..                                                 ...
# 257  Tengo mucha gente en mi vida. Tengo mi familia...
# 258  Una historia hermosa puede ser descrita muy di...
# 259  Una persona famosa es Michael Jordan. Yo piens...
# 260  Tengo una historia horrible durante la vacació...
# 261  Chris Martin es un cantante, pianista y guitar...
#
#                                                 target      id     prompt  \
# 0    Un evento terrible que ocurrió en mi vida hace...  169632   terrible
# 1    Una persona famosa que me inspira es Selena Qu...  159244     famous
# 2    El presidente Trump es muy buen presidente. No...  190771     famous
# 3    En mi vida, yo tengo un persona especial. Mi p...  171906    special
# 4    ﻿  Mis vacaciones perfectas serían ir a la pla...  146799   vacation
# ..                                                 ...     ...        ...
# 257  Tengo mucha gente en mi vida. Tengo a mi famil...  134174    special
# 258  Una historia hermosa puede ser descrita de man...  231920  beautiful
# 259  ﻿Una persona famosa es Michael Jordan. Yo pien...  176089     famous
# 260  Tengo un cuento terrible durante las vacacione...  172548   terrible
# 261  Chris Martin es un cantante, pianista, y guita...  128671     famous
#
#     quarter  course   age  gender l1 language  ...  \
# 0       F18  SPA 24  19.0  Female     English  ...
# 1       S17   SPA 3  19.0  Female     English  ...
# 2       S18   SPA 1  31.0    Male     English  ...
# 3       S19   SPA 3  18.0  Female     English  ...
# 4       S17   SPA 2  19.0  Female     English  ...
# ..      ...     ...   ...     ...         ...  ...
# 257     W19  SPA 21  22.0  Female     English  ...
# 258     S20  SPA 33   NaN      21         NaN  ...
# 259     F17   SPA 1  18.0    Male     English  ...
# 260     F18   SPA 1  19.0  Female    Mandarin  ...
# 261     F17  SPA 21   NaN  Female     English  ...
#
#                                  a personal annotator1  \
# 0                                                  NaN
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3                                                  NaN
# 4    Mi vacaciones perfecto would be ir a la playa ...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259  Una persona famosa es Michael Jordan. Yo pense...
# 260                                                NaN
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                  a personal annotator2  \
# 0                                                  NaN
# 1    Una persona famosa que me inspira es Selena Qu...
# 2                                                  NaN
# 3                                                  NaN
# 4    Mi vacaciones perfecto would be ir a la playa ...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259  Una persona famosa es Michael Jordan. Yo pense...
# 260                                                NaN
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                               gender-number annotator1  \
# 0                                                  NaN
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3                                                  NaN
# 4    [Mi]{mis}<na:ps:det:inan> vacaciones [perfecto...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259  Una persona famosa es Michael Jordan. Yo pense...
# 260                                                NaN
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                               gender-number annotator2  \
# 0                                                  NaN
# 1    Una persona famosa que me inspira es Selena Qu...
# 2                                                  NaN
# 3                                                  NaN
# 4    [Mi]{mis}<na:ps:det:inan> vacaciones [perfecto...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
#
#                                updated anntoation ann1  \
# 0    ﻿Un evento terrible que ocurre en mi vida hace...
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El Presidente Trump es muy buen Presidente, él...
# 3    En mi vida, yo tengo un persona especial. Mi p...
# 4    ﻿  [Mi]{Mis}<na:adj> vacaciones perfecto would...
# ..                                                 ...
# 257  [Yo]{}<pr:su:pron> tengo mucha gente en mi vid...
# 258  Una historia hermosa puede ser describida muy ...
# 259  Una persona famosa es Michael Jordan. [Yo]{}<p...
# 260  Tengo un cuento terrible durante [la]{las}<in:...
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                updated annotation ann2  \
# 0    Un evento terrible que [ocurre]{ocurrió}<fs:st...
# 1    ﻿Una persona famosa que me inspira es Selena Q...
# 2    El Presidente Trump es muy buen Presidente, [é...
# 3    En mi vida, [yo]{}<pr:su:pron> tengo [un]{una}...
# 4    [Mi]{Mis}<na:det> vacaciones [perfecto]{perfec...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260  Tengo un cuento terrible durante [la]{las}<in:...
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                  verbs annotation ann1 verbs annotation ann2  \
# 0                                                  NaN                   NaN
# 1                                                  NaN                   NaN
# 2                                                  NaN                   NaN
# 3                                                  NaN                   NaN
# 4                                                  NaN                   NaN
# ..                                                 ...                   ...
# 257                                                NaN                   NaN
# 258  Una historia hermosa puede ser describida muy ...                   NaN
# 259                                                NaN                   NaN
# 260                                                NaN                   NaN
# 261                                                NaN                   NaN
#
#                                             corrected1  \
# 0    Un evento terrible que ocurrió en mi vida hace...
# 1    Una persona famosa que me inspira es Selena Qu...
# 2    El presidente Trump es muy buen presidente. No...
# 3    En mi vida, yo tengo un persona especial. Mi p...
# 4    ﻿  Mis vacaciones perfectas serían ir a la pla...
# ..                                                 ...
# 257  Tengo mucha gente en mi vida. Tengo a mi famil...
# 258  Una historia hermosa puede ser descrita de man...
# 259  Una persona famosa es Michael Jordan. Creo que...
# 260  Tengo un cuento terrible durante las vacacione...
# 261  Chris Martin es un cantante, pianista, y guita...
#
#                                             corrected2
# 0                                                  NaN
# 1    ﻿Una persona famosa que me inspira es Selena Q...
# 2                                                  NaN
# 3                                                  NaN
# 4    Mis vacaciones perfectas serían ir a la playa ...
# ..                                                 ...
# 257                                                NaN
# 258                                                NaN
# 259  ﻿Una persona famosa es Michael Jordan. Yo pien...
# 260                                                NaN
# 261  Chris Martin es un cantante, pianista y guitar...
#
# [262 rows x 28 columns]

# %%
nulos_por_columna = combined_df.isna().sum()

# Mostrar el resultado
print(nulos_por_columna)
# Out:
# input                         0
# correction                    0
# target                        0
# id                            0
# prompt                        0
# quarter                       0
# course                        6
# age                          27
# gender                        5
# l1 language                  10
# other l1 language(s)        190
# language(s) used at home     83
# language(s) studied         128
# listening comprehension      22
# reading comprehension        22
# speaking ability             22
# writing ability              23
# study abroad                 23
# a personal annotator1       125
# a personal annotator2       145
# gender-number annotator1    127
# gender-number annotator2    187
# updated anntoation ann1       0
# updated annotation ann2      65
# verbs annotation ann1       232
# verbs annotation ann2       262
# corrected1                    0
# corrected2                  154
# dtype: int64

# %%
def build_json(data,file_out,personal=False,gender=False,verb=False):
    resultados = []
    for _,row in data.iterrows():
        
        input = row["input"]
        if personal:
            target = row["a personal annotator1"]
        elif gender:
            target = row["gender-number annotator1"]
        elif verb:
            target = row["verbs annotation ann1"]
        else:
            target = row["target"]
        correction = row["correction"]
        observacion = {"input": input, "target":target, "correction":correction}
        resultados.append(observacion)
    with open(file_out, 'w', encoding='utf-8') as json_file:
        json.dump(resultados, json_file, ensure_ascii=False, indent=4)

# %%
import pandas as pd

# Supongamos que ya tienes tu DataFrame llamado test_df
# test_df = ... (tu código para crear el DataFrame)

# Dataset 1: Seleccionar columnas y eliminar filas con nulos
personal = combined_df[["input","correction",'a personal annotator1']].dropna()

# Dataset 2: Seleccionar columnas y eliminar filas con nulos
gender_number = combined_df[["input","correction",'gender-number annotator1']].dropna()

# Dataset 3: Seleccionar columnas y eliminar filas con nulos
verb = combined_df[["input","correction",'verbs annotation ann1']].dropna()

print(len(personal))
print(len(gender_number))
print(len(verb))
# Out:
# 137
# 135
# 30

# %%
build_json(personal,"llama_tuned/personal_llama_tuned.json",personal=True)

# %%
build_json(gender_number,"llama_tuned/gender_llama_tuned.json",gender=True)

# %%
build_json(verb,"llama_tuned/verb_llama_tuned.json",verb=True)

# %%
import pandas as pd

# Código previo para obtener combined_df ...

# Filtra el DataFrame por género
df_female = combined_df[combined_df['gender'] == 'Female']
df_male = combined_df[combined_df['gender'] == 'Male']

# Opcionalmente, puedes resetear los índices para que comiencen desde 0 en ambos DataFrames
df_female = df_female.reset_index(drop=True)
df_male = df_male.reset_index(drop=True)

print("DataFrame para género femenino:")
print(len(df_female))

print("\nDataFrame para género masculino:")
print(len(df_male))
# Out:
# DataFrame para género femenino:
# 197
#
# DataFrame para género masculino:
# 54

# %%
build_json(df_female,"llama_tuned/female_llama_tuned.json")
build_json(df_male,"llama_tuned/male_llama_tuned.json")

# %%
import pandas as pd

# Obtener los valores únicos de la columna 'prompt'
unique_prompts = combined_df['prompt'].unique()

# Mostrar los valores únicos de la columna 'prompt'
print("Valores únicos en la columna 'prompt':")
print(unique_prompts)

prompts =[]
for idx, i in enumerate(unique_prompts):
    

    build_json(combined_df[combined_df['prompt'] == str(i)],f"llama_tuned/{i}_llama_tuned.json")
# Out:
# Valores únicos en la columna 'prompt':
# ['terrible' 'famous' 'special' 'vacation' 'beautiful' 'chaplin' 'yourself']
